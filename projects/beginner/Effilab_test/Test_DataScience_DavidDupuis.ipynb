# %% [markdown]
# ## Effilab - business case
#
# Effilab bids on keywords on Google Ads for its approximately 10,000 clients. The goal is to achieve the number of conversions promised to the client while spending an optimal budget on adwords. Currently, we have a model optimizing budget and cpc bid (cost per click bid) at the campaign level.
#
# One of our goals to optimize the CPC is to understand the evolution of conversions in function of clicks and impressions.
#
# - **impression**: number of times the ads was shown by Google to a user. It depends, among other factors, on the cpc bid.
# - **CPC**: cost per click
# - **average_position**: average position (rank) in Google result pages.
# - **click**: when a user clicks on an ad
# - **conversion**: when a user did a specific action on the client's website (for example filling a form to get info).
#
# ### Environment
#
# Libraries
#
# - sklearn
# - pandas
# - dask
# - numpy
# - scipy
# - matplotlib
#
# If necessary, one can install an external dependancy using `pip install <library>`

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(
    './dataset.csv',
    engine='python'
)

# %%
df.head()
# Out:
#    Unnamed: 0  customer_id  campaign_id  ad_group_id    keyword_id  \
# 0           0   1551288939   1484080226  56278671566  362396573757
# 1           1   1556604737    744170392  38463123585   94881345918
# 2           2   1559107978   1468647106  62493733088  389043783827
# 3           3   1568651041   1495197792  58813398638  376889097046
# 4           4   1575898898   1078274555  53074066496  403784016698
#
#   keyword_text_matching_query        date  clicks  cost  impressions  \
# 0        +Décorateur +Peintre  2018-08-13       1  1.60            1
# 1            +Peinture +Niort  2018-08-24       1  0.94            1
# 2             Taxi Remiremont  2018-08-02       3  1.76            5
# 3         Serrurerie Merignac  2018-08-24       1  1.40            3
# 4   Casse Automobile Guipavas  2018-08-14       2  0.41            7
#
#    conversions  avg_postion
# 0          0.0     1.000000
# 1          0.0     2.000000
# 2          0.0     1.000000
# 3          0.0     3.000000
# 4          0.0     2.128571

# %%
df.shape
# Out:
# (671614, 12)

# %% [markdown]
# The above data does not represent a list of bids but can be understand like so:
#
# If a user matches a combination of keywords, we are willing to bid the **cost** (CPC). Each row matches a user having performed a keyword search in a day and for whom we have displayed an ad or not, if the bid hasn't been won.

# %% [markdown]
# ### **GOAL:**
#
# **Understand the evolution of conversions in function of clicks and impressions to optimize the CPC.**

# %% [markdown]
# A successful ad, will end in a conversion. Therefore, we need to focus on successful conversions.

# %%
print("# successful conversions: {}".format(df[df['conversions'] >= 1.0].shape[0]))
# Out:
# # successful conversions: 9200

# %% [markdown]
# *There are 671 614 rows in the dataset and only 9200 successes. The # of successes represents 1.37% of all the data available. The data is strongly unbalanced. We are better off analyzing the data then training a model prone to bias.*

# %%
df[['clicks','cost','impressions','conversions','avg_postion']].describe()
# Out:
#               clicks           cost    impressions    conversions  \
# count  671614.000000  671614.000000  671614.000000  671614.000000
# mean        1.250647       1.325704       2.698785       0.013819
# std         1.142853       2.057545      17.301113       0.117806
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.000000       0.340000       1.000000       0.000000
# 50%         1.000000       0.740000       1.000000       0.000000
# 75%         1.000000       1.530000       2.000000       0.000000
# max       101.000000     133.840000    4412.000000       3.000000
#
#          avg_postion
# count  670348.000000
# mean        2.002858
# std         1.245060
# min         1.000000
# 25%         1.000000
# 50%         1.714286
# 75%         3.000000
# max        11.000000

# %% [markdown]
# In the above description of our data, we notice some outliers: the max of cost is 133.84 and the max for impressions is 4412.0. Both of these values seem unlikely.

# %%
df.loc[df['cost'].argmax]
# Out:
# Unnamed: 0                           356371
# customer_id                      4848457658
# campaign_id                      1419282179
# ad_group_id                     55921954015
# keyword_id                     298111539250
# keyword_text_matching_query    +Nid +Guêpes
# date                             2018-08-21
# clicks                                   39
# cost                                 133.84
# impressions                             182
# conversions                               1
# avg_postion                         1.25714
# Name: 356371, dtype: object

# %% [markdown]
# For this outlier, we see that **CPC = 133.84\$** , # of impressions is **182**, # of clicks is **39** and # of conversions is **1**. (Unless cost is the total cost.) It costed the company 5219.76\$ for 32 impressions out of 182 to clicked and have only one conversion.

# %%
df.loc[df['impressions'].argmax]
# Out:
# Unnamed: 0                          549965
# customer_id                     2806996680
# campaign_id                     1343520888
# ad_group_id                    63061628108
# keyword_id                        24283541
# keyword_text_matching_query          velux
# date                            2018-08-16
# clicks                                   1
# cost                                  7.78
# impressions                           4412
# conversions                              0
# avg_postion                        1.00272
# Name: 549965, dtype: object

# %% [markdown]
# For this outlier, we see that **CPC = 7.78\$**, # of impressions is **4412**, # of clicks is **1** and # of conversions is **0**. It cost the company 7.78\$ to get a single impression out of 4412 to be clicked on with no ROI.

# %% [markdown]
# To understand the quality of our bidding, lets define the success rate of a bid as the probability that a winning bid will generate a conversion.
#
# **Success rate (SR) = (clicks / impressions) \* (conversions / clicks)**
#
# Using the two outliers above:
# * SR(1) = 0.00525
# * SR(2) = 0
#
# On the other hand, we should define the true cost or loss. Indeed, one can bid 1,000\$ CPC, generate 1,000 impressions and have no clicks, this will cost him nothing. The **True Cost (TC) = cpc \* clicks**
#
# Therefore with the same outliers:
# * TC(1) = 5219.76\$
# * TC(2) = 7.78\$

# %%
ax = sns.distplot(df['cost'],kde=False)
ax.set_yscale('log')

# %%
ax = sns.distplot(df['impressions'],kde=False)
ax.set_yscale('log')

# %%
ax = sns.distplot(df['conversions'],kde=False)
ax.set_yscale('log')

# %%
sns.pairplot(df[['clicks','cost','impressions','conversions']])

# %%
print("Correlation Matrix")
corr = df.corr()
sns.heatmap(corr, xticklabels=corr.columns.values,yticklabels=corr.columns.values)
# Out:
# Correlation Matrix

# %% [markdown]
# In this correlation matrix, we clearly see the lack of correlation between conversions and every other value except for clicks and cost. And clicks are correlated with impressions. Both of these observations are obvious.

# %% [markdown]
# Applying the Success Rate to our data

# %%
df['success rate'] = (df['clicks'] / df['impressions']) * (df['conversions'] / df['clicks'])

# %%
df[df['success rate'] > 0]
# Out:
#         Unnamed: 0  customer_id  campaign_id  ad_group_id    keyword_id  \
# 23              23   1981953400    992972774  51267100276  332423377844
# 62              62   1451166696    740942785  37972783639   62768405299
# 75              75   2518150427   1408197043  55768246256  298905819785
# 195            195   4681269164   1057091228  52732597659  324323916376
# 207            207   4915040676    806927517  48081109375  301249618476
# 225            225   5393309776   1492972280  63174216888  297443208368
# 287            287   6896861029   1360585408  51262562061  417142622626
# 517            517   2185297915    849075003  45086639985  323041622092
# 551            551   2827657396   1416036428  55985808416  452528377125
# 575            575   3568701700   1070524507  54377811512  295849970606
# 649            649   5313367835    740115356  39067092219   54680839442
# 839            839   1575898898   1065439364  51867598243  311384334665
# 878            878   1370281854   1349017841  51678082982  388547428444
# 890            890   2314299962   1043294104  55741060989  296613016306
# 903            903   2555422388    939139605  46499741973  296193515693
# 908            908   2628423847    938559965  64203008388  453691051661
# 944            944   3633240097   1010438349  50096669456  390860445330
# 1067          1067   6269571268   1072850332  56560362430  320054149874
# 1300          1300   2891867627   1298782685  60100327344    2610114201
# 1375          1375   4118764613   1456083086  59505709194  298492548399
# 1412          1412   5105730758   1061208434  53770830644  303331237322
# 1471          1471   6396095595   1042908711  59652952028  299850920772
# 1626          1626   9736678595   1131405259  53755682315  299688852880
# 1628          1628   9807249619    924920342  45733665025  302204066303
# 1662          1662   2083043092   1023876718  49560173959  394927680622
# 1716          1716   2875682935   1467925384  54456815902  296917814610
# 1758          1758   3822525849    664790129  49378296927  294894698147
# 1799          1799   4646117474   1184270528  51946258766  337803942365
# 1835          1835   5480351098   1070271554  51920688389  451137427677
# 1887          1887   7095462874    948183549  47170187236  351909688247
# ...            ...          ...          ...          ...           ...
# 669881      669881   8211811272    652780244  31382068005  193318580719
# 669911      669911   7786661184   1021191115  51899716762  342695480534
# 669941      669941   9067079142    992293197  63854178868  296387824490
# 669957      669957   9303122205   1487570524  57223733653  305044813870
# 670020      670020   1537246227   1065440789  58683262524   20839241052
# 670024      670024   1692160484   1341662301  53492296293  430772123471
# 670091      670091   3101453772   1367370422  57162528360  439638786691
# 670115      670115   3678974182    720118016  36862591879  403168281786
# 670345      670345   8811752301    971811296  48451878695  299850915092
# 670471      670471   3030314405    980207251  47268353023  350081938247
# 670484      670484   3375092217   1045738691  50809401749  298266753080
# 670598      670598   5566650045   1450681167  56271882197  387001363839
# 670688      670688   8334119635   1081433406  56057631269  295849831886
# 670690      670690   8405243884    993129791  48800551906  296654398033
# 670739      670739   8928776105   1468732938  56993634636  302989127928
# 670759      670759   9319763696   1013958445  49967684356  309915404851
# 670837      670837   1929874603    958158384  53308449971  323041560212
# 670843      670843   2185297915    856290903  46152455969  326818583937
# 670862      670862   2556671676    661515835  43648215091  173976025241
# 670867      670867   2701756296   1035372457  50583632573  296620567631
# 670943      670943   3437693800   1422980101  56191926936  303591732161
# 671196      671196   9676354256   1070535007  52767079832  417621950088
# 671273      671273   2429892937   1013014741  49511780373  415545183277
# 671311      671311   3183061101   1469585697  55695013663  325925859973
# 671344      671344   3919463911    965877332  46189719537  310739034936
# 671381      671381   4937076444    700641839  44799795592  337803956565
# 671449      671449   7079291394    970331686  47904179450      59570388
# 671507      671507   7708141560   1051986653  50619104094  387075992045
# 671535      671535   8211811272    652779989  31381973725  190282076906
# 671567      671567   8965754896   1052680300  55644383510  408582864686
#
#                    keyword_text_matching_query        date  clicks   cost  \
# 23                       +Prix +Chape +Liquide  2018-08-28       1   0.96
# 62                          Jardinage Domicile  2018-08-17       2   1.30
# 75                     +Maçonnerie +Entreprise  2018-08-31       3   2.64
# 195                      +Societe +Demenageurs  2018-08-24       1   2.23
# 207                             +Volet +Troyes  2018-08-09       2   2.81
# 225                           +Fosse +Septique  2018-08-17       3   8.48
# 287                  Déménagement Petit Volume  2018-08-09       1   2.40
# 517                      Véranda Bioclimatique  2018-08-16       1   1.01
# 551                   +Pisciniste +Saint +Malo  2018-08-02       1   1.09
# 575                   Climatisation Automobile  2018-08-20       1   1.28
# 649                              +Dératisation  2018-08-12       1   0.18
# 839                     +Pièce +Detachee +Auto  2018-08-03       1   0.22
# 878                                   +Voyante  2018-08-12       4   2.48
# 890                                +Frigoriste  2018-08-28       1   0.40
# 903                 +Caméra +Vidéosurveillance  2018-08-14       1   3.24
# 908      +Installateur +- +Portail +coulissant  2018-08-16       1   1.86
# 944                        +bureau +étude +sol  2018-08-15       1   0.75
# 1067                    +Barrière +Automatique  2018-08-21       1   1.16
# 1300                           poele a granule  2018-08-17       1   0.83
# 1375                                 Assurance  2018-08-03       6   2.31
# 1412                       Prothèse Capillaire  2018-08-26       1   0.20
# 1471                  +Fenêtre +PVC +fabricant  2018-08-28       2   2.18
# 1626                           +déchets +Benne  2018-08-05       1   0.26
# 1628                              +Volet +Lyon  2018-08-09       3   6.02
# 1662             Administrateur système réseau  2018-08-07       1   0.84
# 1716                          +Devis +Enseigne  2018-08-06       1   1.12
# 1758           +Nettoyage +Toiture +Entreprise  2018-08-20       1   1.05
# 1799                         +Réparateur +Toit  2018-08-12       2  15.56
# 1835                       +Nettoyage +Voiture  2018-08-13       1   0.16
# 1887               +electromenager +reparateur  2018-08-03       1   0.24
# ...                                        ...         ...     ...    ...
# 669881  +Installation +Volet +Roulant +Solaire  2018-08-23       1   1.68
# 669911                        +Parquet +Cannes  2018-08-13       2   2.14
# 669941                      +Fioul +Domestique  2018-08-17       4   1.10
# 669957                        +société +levage  2018-08-07       1   1.77
# 670020                 +entreprise +rénovation  2018-08-28       3   4.98
# 670024                  +Profil +Saint +Benoit  2018-08-23       1   0.03
# 670091      +formation +caces +Alpes-Maritimes  2018-08-11       1   0.10
# 670115         +Regroupement +Familial +Avocat  2018-08-13       2   1.74
# 670345               +Entreprise +Fenêtre +PVC  2018-08-11       1   4.10
# 670471                    +Pergolas +Aluminium  2018-08-29       1   1.16
# 670484                          +Pose +Portail  2018-08-15       1  10.71
# 670598                 entreprise pose portail  2018-08-12       1   0.86
# 670688                            +Carrosserie  2018-08-04       1   0.24
# 670690          +Fabrication +Volet +Aluminium  2018-08-16       1   1.28
# 670739                      +Joint +Caoutchouc  2018-08-21       2   0.38
# 670759                       +Isolation +Devis  2018-08-08       1   4.99
# 670837                 +Véranda +Bioclimatique  2018-08-14       1   1.69
# 670843                           veranda Macon  2018-08-02       2   1.76
# 670862                    +Traitement +Abeille  2018-08-13       1   0.51
# 670867                     +Cloture +PVC +Pose  2018-08-10       1   1.45
# 670943               +Entreprise +Désamiantage  2018-08-28       3   6.69
# 671196            +Plaquettes +Freins +Changer  2018-08-06       1   1.10
# 671273                      +Déménager +Rennes  2018-08-14       2   8.82
# 671311                          +tole +bardage  2018-08-07       1   0.36
# 671344                        +Tableau +Ancien  2018-08-14       1   0.17
# 671381                       +Toiture +Artisan  2018-08-20       1   1.26
# 671449                              demenageur  2018-08-02       3   6.80
# 671507                           +Peintre +Pau  2018-08-13       1   0.74
# 671535             +Fabrication +Porte +Garage  2018-08-23       1   1.68
# 671567                          +Livreur +Lyon  2018-08-15       1   0.49
#
#         impressions  conversions  avg_postion  success rate
# 23                6          1.0     2.000000      0.166667
# 62                2          1.0     3.000000      0.500000
# 75                2          1.0     2.500000      0.500000
# 195               1          1.0     4.000000      1.000000
# 207               3          2.0     2.333333      0.666667
# 225               5          1.0     1.400000      0.200000
# 287               1          1.0     1.000000      1.000000
# 517               4          1.0     3.750000      0.250000
# 551               2          1.0     1.000000      0.500000
# 575               1          1.0     1.000000      1.000000
# 649               1          1.0     6.000000      1.000000
# 839               1          1.0     2.000000      1.000000
# 878               6          1.0     2.316667      0.166667
# 890               2          1.0     3.000000      0.500000
# 903               2          1.0     2.500000      0.500000
# 908               1          1.0     2.000000      1.000000
# 944               2          1.0     5.500000      0.500000
# 1067              1          1.0     2.000000      1.000000
# 1300              1          1.0     2.000000      1.000000
# 1375              6          1.0     3.000000      0.166667
# 1412              2          1.0     2.000000      0.500000
# 1471              1          1.0     4.000000      1.000000
# 1626              1          1.0     3.000000      1.000000
# 1628              3          1.0     2.333333      0.333333
# 1662              1          1.0     1.000000      1.000000
# 1716              1          1.0     2.000000      1.000000
# 1758              1          1.0     2.000000      1.000000
# 1799              1          1.0     2.000000      1.000000
# 1835              1          1.0     2.000000      1.000000
# 1887              1          1.0     2.000000      1.000000
# ...             ...          ...          ...           ...
# 669881            1          1.0     3.000000      1.000000
# 669911            1          1.0     2.000000      1.000000
# 669941            6          1.0     2.166667      0.166667
# 669957            1          1.0     1.000000      1.000000
# 670020            2          1.0     2.000000      0.500000
# 670024            1          1.0     1.000000      1.000000
# 670091            1          1.0     1.000000      1.000000
# 670115            2          1.0     2.000000      0.500000
# 670345            1          1.0     1.000000      1.000000
# 670471            1          1.0     1.000000      1.000000
# 670484            1          1.0     1.000000      1.000000
# 670598            1          1.0     2.000000      1.000000
# 670688            1          1.0     3.000000      1.000000
# 670690            1          1.0     2.000000      1.000000
# 670739            2          1.0     6.000000      0.500000
# 670759            1          1.0     1.000000      1.000000
# 670837            1          1.0     1.000000      1.000000
# 670843            3          1.0     2.000000      0.333333
# 670862            1          1.0     1.000000      1.000000
# 670867            1          1.0     1.000000      1.000000
# 670943            2          1.0     1.000000      0.500000
# 671196            1          1.0     4.000000      1.000000
# 671273            2          1.0     2.000000      0.500000
# 671311            1          1.0     1.000000      1.000000
# 671344            1          1.0     6.000000      1.000000
# 671381            2          1.0     1.500000      0.500000
# 671449           13          1.0     4.230769      0.076923
# 671507            2          1.0     2.000000      0.500000
# 671535            1          1.0     4.000000      1.000000
# 671567            1          1.0     3.000000      1.000000
#
# [9176 rows x 13 columns]

# %% [markdown]
# Using the computed success rate, we can easily see how effective a bidding strategy is. We can also see some surprising phenomena, for instance, we can observe multiple clicks for a single impression

# %%
df[df['success rate'] > 0].shape
# Out:
# (9176, 13)

# %%
df['success rate'] = df['success rate'].fillna(0)

# %%
df.loc[df['success rate'].argmax()]
# Out:
# Unnamed: 0                                  63677
# customer_id                            3919463911
# campaign_id                             999487148
# ad_group_id                           56299003144
# keyword_id                           369431224773
# keyword_text_matching_query    +Brocanteur +Paris
# date                                   2018-08-10
# clicks                                          2
# cost                                         0.52
# impressions                                     1
# conversions                                     2
# avg_postion                                     1
# success rate                                    2
# Name: 63677, dtype: object

# %% [markdown]
# It would be interesting to compare the success rate based on the keywords used.

# %%
df[(df['keyword_text_matching_query'].str.contains("portail") | df['keyword_text_matching_query'].str.contains("Portail"))   & df['success rate'] > 0].head()
# Out:
#        Unnamed: 0  customer_id  campaign_id  ad_group_id    keyword_id  \
# 908           908   2628423847    938559965  64203008388  453691051661
# 5462         5462   3537779176   1413844544  59684210150  297319684938
# 12072       12072   9804479642   1426663438  59814570601  300241813613
# 12802       12802   7222174435   1473448291  57837822380  307127801019
# 14533       14533   8760002623   1434553865  56257601476  345442780529
#
#                  keyword_text_matching_query        date  clicks  cost  \
# 908    +Installateur +- +Portail +coulissant  2018-08-16       1  1.86
# 5462                             Portail Alu  2018-08-16       3  2.84
# 12072                   Motorisation Portail  2018-08-02       1  1.39
# 12802                          Portail Royan  2018-08-12       1  1.38
# 14533                       Portail Penmarch  2018-08-08       1  0.29
#
#        impressions  conversions  avg_postion  success rate
# 908              1          1.0        2.000          1.00
# 5462             4          1.0        4.225          0.25
# 12072            5          1.0        2.800          0.20
# 12802            1          1.0        1.000          1.00
# 14533            1          1.0        1.000          1.00

# %%
df[df['campaign_id'] == 938559965]
# Out:
#         Unnamed: 0  customer_id  campaign_id  ad_group_id    keyword_id  \
# 908            908   2628423847    938559965  64203008388  453691051661
# 44716        44716   2628423847    938559965  64203009348  453691053301
# 232948      232948   2628423847    938559965  56553119682  298266754480
# 362366      362366   2628423847    938559965  64203009748  298266771240
# 597604      597604   2628423847    938559965  64203010268  296401258016
#
#                   keyword_text_matching_query        date  clicks  cost  \
# 908     +Installateur +- +Portail +coulissant  2018-08-16       1  1.86
# 44716                 +pose +portail +- +prix  2018-08-06       1  2.28
# 232948                      Fabricant Portail  2018-08-10       1  1.72
# 362366                          Poser Portail  2018-08-08       2  3.72
# 597604                       +poseur +portail  2018-08-10       1  1.66
#
#         impressions  conversions  avg_postion  success rate
# 908               1          1.0          2.0           1.0
# 44716             1          0.0          2.0           0.0
# 232948            1          0.0          4.0           0.0
# 362366            1          0.0          2.0           0.0
# 597604            1          0.0          2.0           0.0

# %% [markdown]
# We may also want to define the **cost of conversion = (clicks * CPC) / conversion** If there are no conversions, the cost of conversion is that of **clicks * CPC** because although there were no conversions, that's how much was spent.

# %%
df['conversion cost'] = np.where(df['conversions'] > 0, (df['clicks'] * df['cost']) / df['conversions'], (df['clicks'] * df['cost']))

# %%
df[df['conversion cost'] > 0].head()
# Out:
#    Unnamed: 0  customer_id  campaign_id  ad_group_id    keyword_id  \
# 0           0   1551288939   1484080226  56278671566  362396573757
# 1           1   1556604737    744170392  38463123585   94881345918
# 2           2   1559107978   1468647106  62493733088  389043783827
# 3           3   1568651041   1495197792  58813398638  376889097046
# 4           4   1575898898   1078274555  53074066496  403784016698
#
#   keyword_text_matching_query        date  clicks  cost  impressions  \
# 0        +Décorateur +Peintre  2018-08-13       1  1.60            1
# 1            +Peinture +Niort  2018-08-24       1  0.94            1
# 2             Taxi Remiremont  2018-08-02       3  1.76            5
# 3         Serrurerie Merignac  2018-08-24       1  1.40            3
# 4   Casse Automobile Guipavas  2018-08-14       2  0.41            7
#
#    conversions  avg_postion  success rate  conversion cost
# 0          0.0     1.000000           0.0             1.60
# 1          0.0     2.000000           0.0             0.94
# 2          0.0     1.000000           0.0             5.28
# 3          0.0     3.000000           0.0             1.40
# 4          0.0     2.128571           0.0             0.82

# %%
df[df['conversion cost'] > 0]['conversion cost'].describe()
# Out:
# count    617765.000000
# mean          2.901493
# std          27.784517
# min           0.010000
# 25%           0.440000
# 50%           0.940000
# 75%           2.100000
# max       12046.580000
# Name: conversion cost, dtype: float64

# %% [markdown]
# Here we see how much each conversion cost. Because there are few conversions, there isn't much to analyze if we look at all the data. So we look at the description of all successful conversions. We see that the average conversion cost 2.90$.

# %%
ax = sns.distplot(df[df['conversion cost'] > 0]['conversion cost'],kde=False)
ax.set_yscale('log')

# %% [markdown]
# With this distribution, we see some of the outlier, in particular one big one of 12,046.58$.

# %%
df[(df['conversion cost'] > 0) & (df['conversion cost'] < 4000)]['conversion cost'].describe()
# Out:
# count    617761.000000
# mean          2.856839
# std          20.144607
# min           0.010000
# 25%           0.440000
# 50%           0.940000
# 75%           2.100000
# max        3825.800000
# Name: conversion cost, dtype: float64

# %% [markdown]
# We suppose that the CPC value matters independently for each campaign. So we want to analyze how the conversion cost changes for each campaign.

# %%
df.groupby(['campaign_id'])['conversion cost'].mean()
# Out:
# campaign_id
# 605239889     0.960667
# 614675200     2.440000
# 614675716     2.670000
# 616859692     1.558333
# 616859983     0.331429
# 616861333     0.931111
# 616861339     2.441250
# 616863337     1.117500
# 616863502     0.460000
# 616864798     4.243333
# 616864924     3.374762
# 616865677     0.803077
# 616865680     0.785161
# 616865725     0.774800
# 616865749     1.386667
# 616865926     0.690000
# 616870237     2.040000
# 616870984     1.622000
# 616871197     0.500000
# 616871926     0.353750
# 616871932     0.404375
# 616872178     1.211923
# 616888520     0.616923
# 616888523     0.680000
# 616888526     0.365000
# 616889975     0.160000
# 616891421     1.410678
# 616891424     2.380000
# 616892810     0.160000
# 616893332     1.751250
#                 ...
# 1527805674    0.236000
# 1527806547    0.340000
# 1527806847    0.120000
# 1527808059    0.195000
# 1527808065    0.216000
# 1527811323    0.190000
# 1527814680    0.385000
# 1527814731    0.366667
# 1527814995    0.400000
# 1527815025    0.080000
# 1527815181    0.735000
# 1527815193    0.306000
# 1527815757    0.141667
# 1527815988    0.114000
# 1527816132    0.290882
# 1527816210    0.130000
# 1527816216    0.555000
# 1527816384    0.276667
# 1527816387    0.260000
# 1527816651    0.120000
# 1527816699    0.137500
# 1527817161    0.170000
# 1527817899    0.346000
# 1527821907    0.116667
# 1534409519    2.010000
# 1534906730    0.210000
# 1534907432    0.220000
# 1535177494    0.545000
# 1535333211    0.620000
# 1535348112    0.610000
# Name: conversion cost, dtype: float64

# %%
df.groupby(['campaign_id'])['conversion cost'].aggregate(['mean','std','min','max'])
# Out:
#                  mean       std   min    max
# campaign_id
# 605239889    0.960667  1.590222  0.22   6.36
# 614675200    2.440000       NaN  2.44   2.44
# 614675716    2.670000       NaN  2.67   2.67
# 616859692    1.558333  1.540294  0.24   4.32
# 616859983    0.331429  0.087451  0.19   0.43
# 616861333    0.931111  0.592272  0.32   2.36
# 616861339    2.441250  2.431774  0.35   6.99
# 616863337    1.117500  1.681513  0.00   6.08
# 616863502    0.460000  0.309946  0.19   1.20
# 616864798    4.243333  4.609863  1.36   9.56
# 616864924    3.374762  7.606174  0.00  36.44
# 616865677    0.803077  0.940620  0.00   3.57
# 616865680    0.785161  0.955642  0.00   4.16
# 616865725    0.774800  1.298939  0.00   4.76
# 616865749    1.386667  1.516062  0.00   5.80
# 616865926    0.690000       NaN  0.69   0.69
# 616870237    2.040000       NaN  2.04   2.04
# 616870984    1.622000  2.061097  0.00   4.98
# 616871197    0.500000  0.098995  0.43   0.57
# 616871926    0.353750  0.290020  0.00   1.48
# 616871932    0.404375  0.351971  0.00   1.44
# 616872178    1.211923  2.239097  0.00  15.76
# 616888520    0.616923  0.903386  0.00   2.82
# 616888523    0.680000       NaN  0.68   0.68
# 616888526    0.365000  0.305567  0.06   0.84
# 616889975    0.160000  0.085049  0.00   0.24
# 616891421    1.410678  1.902790  0.00  12.44
# 616891424    2.380000       NaN  2.38   2.38
# 616892810    0.160000  0.170587  0.02   0.35
# 616893332    1.751250  0.538077  1.04   2.34
# ...               ...       ...   ...    ...
# 1527805674   0.236000  0.205256  0.10   0.60
# 1527806547   0.340000       NaN  0.34   0.34
# 1527806847   0.120000       NaN  0.12   0.12
# 1527808059   0.195000  0.035355  0.17   0.22
# 1527808065   0.216000  0.024083  0.19   0.25
# 1527811323   0.190000  0.080000  0.11   0.27
# 1527814680   0.385000  0.023805  0.36   0.41
# 1527814731   0.366667  0.069462  0.28   0.49
# 1527814995   0.400000  0.183576  0.26   0.88
# 1527815025   0.080000       NaN  0.08   0.08
# 1527815181   0.735000  0.827315  0.15   1.32
# 1527815193   0.306000  0.058566  0.21   0.35
# 1527815757   0.141667  0.065243  0.06   0.22
# 1527815988   0.114000  0.013416  0.10   0.13
# 1527816132   0.290882  0.210387  0.00   1.00
# 1527816210   0.130000       NaN  0.13   0.13
# 1527816216   0.555000  0.487678  0.16   1.20
# 1527816384   0.276667  0.281129  0.09   0.60
# 1527816387   0.260000       NaN  0.26   0.26
# 1527816651   0.120000       NaN  0.12   0.12
# 1527816699   0.137500  0.009574  0.13   0.15
# 1527817161   0.170000  0.101980  0.00   0.29
# 1527817899   0.346000  0.307357  0.00   0.96
# 1527821907   0.116667  0.023094  0.09   0.13
# 1534409519   2.010000       NaN  2.01   2.01
# 1534906730   0.210000       NaN  0.21   0.21
# 1534907432   0.220000       NaN  0.22   0.22
# 1535177494   0.545000  0.247487  0.37   0.72
# 1535333211   0.620000       NaN  0.62   0.62
# 1535348112   0.610000       NaN  0.61   0.61
#
# [43804 rows x 4 columns]

# %% [markdown]
# We see in the above table, how the cost of conversion varies from campaign.

# %%
corr = df[['campaign_id','clicks','cost','conversions','success rate','conversion cost']].corr()
sns.heatmap(corr, xticklabels=corr.columns.values,yticklabels=corr.columns.values)

# %% [markdown]
# ## Conclusion
#
# It's hard to determine much from this data because it's not specific to each bid nor do we have enough conversions to assess what may impact successful conversion. Some of the column values are not clearly defined. We also do not know the budget for each campaign. This is a major element in any RTB environment.
#
# Our goal was to better understand the evolution of conversions based on clicks and impressions. However, it's clear that the more impressions, the more clicks and the more clicks, the more conversions.
#
# While this is clearly observable, we have noticed that the cost of conversion varies for each campaign and that some campaign have a much higher conversion cost than others. These are likely to be the campaign for which we'll want to improve the CPC to reduce the Conversion Cost.
#
# This is a complex problem because we want to minimize the overall cost but maximize the number of conversions. If we lower the CPC, we are less likely to have high impressions, therefore less clicks and therefore less conversions. However, if we increase the CPC, we might be spending more for clicks we would have gotten with a lower CPC. Knowing the cost of conversion allows us to focus on a single variable. Our objective is to minimize it.
